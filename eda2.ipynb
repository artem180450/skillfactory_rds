# %% [markdown]
# ## Описание датасета##
# Посмотрим на переменные, которые содержит датасет:
#
# 1. __school__ — аббревиатура школы, в которой учится ученик
# 2. __sex__ — пол ученика ('F' - женский, 'M' - мужской)
# 3. __age__ — возраст ученика (от 15 до 22)
# 4. __address__ — тип адреса ученика ('U' - городской, 'R' - за городом)
# 5. __famsize__ — размер семьи('LE3' <= 3, 'GT3' >3)
# 6. __Pstatus__ — статус совместного жилья родителей ('T' - живут вместе 'A' - раздельно)
# 7. __Medu__ — образование матери (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее)
# 8. __Fedu__ — образование отца (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее)
# 9. __Mjob__ — работа матери ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое).
# 10. __Fjob__ — работа отца ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое)
# 11. __reason__ — причина выбора школы ('home' - близость к дому, 'reputation' - репутация школы, 'course' - образовательная программа, 'other' - другое)
# 12. __guardian__ — опекун ('mother' - мать, 'father' - отец, 'other' - другое)
# 13. __traveltime__ — время в пути до школы (1 - <15 мин., 2 - 15-30 мин., 3 - 30-60 мин., 4 - >60 мин.)
# 14. __studytime__ — время на учёбу помимо школы в неделю (1 - <2 часов, 2 - 2-5 часов, 3 - 5-10 часов, 4 - >10 часов)
# 15. __failures__ — количество внеучебных неудач (n, если 1<=n<3, иначе 0)
# 16. __schoolsup__ — дополнительная образовательная поддержка (yes или no)
# 17. __famsup__ — семейная образовательная поддержка (yes или no)
# 18. __paid__ — дополнительные платные занятия по математике (yes или no)
# 19. __activities__ — дополнительные внеучебные занятия (yes или no)
# 20. __nursery__ — посещал детский сад (yes или no)
# 21. __higher__ — хочет получить высшее образование (yes или no)
# 22. __internet__ — наличие интернета дома (yes или no)
# 23. __romantic__ — в романтических отношениях (yes или no)
# 24. __famrel__ — семейные отношения (от 1 - очень плохо до 5 - очень хорошо)
# 25. __freetime__ — свободное время после школы (от 1 - очень мало до 5 - очень мого)
# 26. __goout__ — проведение времени с друзьями (от 1 - очень мало до 5 - очень много)
# 27. __health__ — текущее состояние здоровья (от 1 - очень плохо до 5 - очень хорошо)
# 28. __absences__ — количество пропущенных занятий
# 29. __score__ — баллы по госэкзамену по математике

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# показываем все столбцы
pd.set_option('display.max_columns', None)  # показывать все столбцы
pd.set_option('display.max_rows', 50)  # показывать больше строк
pd.set_option('display.max_columns', 50)  # показывать больше колонок

# %%
# читаем файл
sc = pd.read_csv('stud_math.csv')

# %%
# смотрим, что есть
sc.info()
sc.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 30 columns):
# school                 395 non-null object
# sex                    395 non-null object
# age                    395 non-null int64
# address                378 non-null object
# famsize                368 non-null object
# Pstatus                350 non-null object
# Medu                   392 non-null float64
# Fedu                   371 non-null float64
# Mjob                   376 non-null object
# Fjob                   359 non-null object
# reason                 378 non-null object
# guardian               364 non-null object
# traveltime             367 non-null float64
# studytime              388 non-null float64
# failures               373 non-null float64
# schoolsup              386 non-null object
# famsup                 356 non-null object
# paid                   355 non-null object
# activities             381 non-null object
# ...

# %%
# посмотрим на столбец с целевой переменной score - в ней есть пропуски
# их немного, можно удалить, чтобы не мешались
# возможно позже, после анализа данных, можно будет их как-то правильно заполнить
sc.dropna(subset=['score'], inplace=True)
sc.info()
total = sc.index.nunique()
print('total', total)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 389 entries, 0 to 394
# Data columns (total 30 columns):
# school                 389 non-null object
# sex                    389 non-null object
# age                    389 non-null int64
# address                374 non-null object
# famsize                362 non-null object
# Pstatus                344 non-null object
# Medu                   386 non-null float64
# Fedu                   365 non-null float64
# Mjob                   370 non-null object
# Fjob                   353 non-null object
# reason                 372 non-null object
# guardian               358 non-null object
# traveltime             361 non-null float64
# studytime              382 non-null float64
# failures               367 non-null float64
# schoolsup              380 non-null object
# famsup                 351 non-null object
# paid                   350 non-null object
# activities             375 non-null object
# ...

# %%
# выясним, как распределены оценки
# распределение почти нормальное, за исключением нулевого балла - что-то там не то

score = sc['score'].value_counts().sort_index()
display(score)
sns.barplot(x=score.index, y=score.values)
# Out:
# 0.0      37
# 20.0      1
# 25.0      7
# 30.0     15
# 35.0      9
# 40.0     31
# 45.0     27
# 50.0     54
# 55.0     46
# 60.0     31
# 65.0     31
# 70.0     27
# 75.0     33
# 80.0     16
# 85.0      6
# 90.0     12
# 95.0      5
# 100.0     1
# Name: score, dtype: int64

# %% [markdown]
# ### Далее каждый столбец

# %%
# Название школы - выше было видно, что пропусков нет
# всего два значения, причем  MS - либо маленькая школа, либо, старшеклассников там мало
# Быстрый поиск в Интернете не дал какой-либо подсказки, единственное, что нечто подобное есть в Канаде:
# Grande Prairie school
# https://www.google.com/maps/place/Grande+Prairie+Public+School+Division/@55.1580811,-118.8044525,12.5z/data=!4m8!1m2!2m1!1sGrande+Prairie+school!3m4!1s0x539096aa8943f1e1:0xfa8fce569a9461af!8m2!3d55.1875333!4d-118.8001765
# но MS там нигде не упоминается, если только MS=Middle School
# хотя, интернет говорит, что Middle в среднем по миру от 11 до 14 лет, значит нам не подходит

sc['school'].value_counts()
# Out:
# GP    344
# MS     45
# Name: school, dtype: int64

# %%
# для упрощения рисования boxplot, сделаем функцию
# где x - колонка для оси X, y - колонка для оси Y
# заодно поменяем цвет у медианы


def draw_box(x, y, swap=False, hue=None, data=sc, thresh=None):
    # функция вываливается с ошибкой при нечисловых значениях, но для в основном пойдет
    # не хочется заморачиваться еще с проверкой типов
    if swap:
        x, y = y, x  # поменять местами оси
        
    fig, ax = plt.subplots(figsize=(14, 4))

    if thresh:  # для верхней границы отображения
        x1 = data[data[x] < thresh][x]
        y1 = data[data[x] < thresh][y]
    else:
        x1 = data[x]
        y1 = data[y]

    if hue:  # если надо делать дополнительную разбивку
        sns.boxplot(x=x1, y=y1, hue=data[hue],
                    ax=ax, medianprops={'color': 'red'})
    else:
        sns.boxplot(x=x1, y=y1, ax=ax, medianprops={'color': 'red'})

    ax.set_title('Boxplot for ' + y)
    plt.show()

# %%
# распределение баллов по школам
# хотя медианное значение выше в школе GP, в школе MS в целом успеваемость лучше
# практически все, у кого 20 и меньше баллов, находятся в GP
draw_box('score', 'school')

# %%
# пол: мальчики учатся лучше девочек

draw_box('score', 'sex')

# %%
# возраст: пропусков нет, в среднем в 15-18 лет одинаковая медиана
# но по полам есть различия
print(sc['age'].value_counts(dropna=False),
      '\n', 'age all:', sc['age'].count())
draw_box('age', 'score')
draw_box('age', 'score', hue='sex')
# Out:
# 16    103
# 17     98
# 15     82
# 18     80
# 19     21
# 20      3
# 22      1
# 21      1
# Name: age, dtype: int64
#  age all: 389

# %%
# сделаем общую функцию для показа основных параметров
def show_common(x, swap=False, hue=None, data=sc):
    print(data[x].value_counts(dropna=False),
          '\n', x + ' all:', data[x].count())

# %%
# адрес: 15 пропусков
# у городских немного лучше результат (так себе вывод - я ж так и не выяснил, кто там в пригороде живет)
# по идее, этот параметр никак не должен влиять на предсказания

show_common('address')
draw_box('address', 'score', swap=True)
draw_box('address', 'score', swap=True, hue='school')
# Out:
# U      291
# R       83
# NaN     15
# Name: address, dtype: int64
#  address all: 374

# %%
# посмотрим, каким значение лучше заполнить пропуски в адресе, если опираться на время в пути traveltime
# для каждой школы
# медианное значение для адреса U - 1, для R - 2
s_gp = sc[sc['school'] == 'GP']
s_ms = sc[sc['school'] == 'MS']

# print('GP traveltime:',trav_gp)
# print('MS traveltime:',trav_ms)
# for i in schol['address'].unique():
#     print(i,s_ms[s_ms['address']==i]['traveltime'].value_counts())
#     print(i,s_gp[s_gp['address']==i]['traveltime'].value_counts())

# draw_box('traveltime','address',hue='school', swap=False)
draw_box('traveltime', 'address', swap=False)
print('median for U:', sc[sc['address'] == 'U']['traveltime'].median())
print('median for R:', sc[sc['address'] == 'R']['traveltime'].median())
# Out:
# median for U: 1.0
# median for R: 2.0

# %%
# сразу посмотрим на traveltime - там ведь тоже могут быть пропуски
# да, их 28
show_common('traveltime')
# Out:
# 1.0    239
# 2.0     94
# NaN     28
# 3.0     21
# 4.0      7
# Name: traveltime, dtype: int64
#  traveltime all: 361

# %%
# заменим пустые значения address на основе медианы,
# т.е если 1 - то address будет U, а все, что больше - R и не будем менять ничего, если traveltime == NaN
# на самом деле это может быть не так, если ученик живет в пригороде, но дойти ему не долго
# иди же он любит пешком ходить и живет в городе
# и мы вообще не знаем месторасположения школ

sc['address'] = sc.apply(lambda x: 'U' if x.traveltime < 2
                         else ('R' if x.traveltime > 1
                               else x.address), axis=1)

# %%
# осталось только 3 NaN
show_common('address')
sc[(sc['address'].isna())]
# Out:
# U      257
# R      129
# NaN      3
# Name: address, dtype: int64
#  address all: 386
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 241     GP   M   17     NaN     LE3       A   4.0   4.0  teacher    other
# 348     GP   F   17     NaN     GT3       T   4.0   3.0   health    other
# 372     MS   F   17     NaN     GT3       T   2.0   2.0    other  at_home
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 241      course   mother         NaN        2.0       0.0        no    yes
# 348  reputation   mother         NaN        3.0       0.0        no    yes
# 372        home   mother         NaN        3.0       0.0        no     no
#
#     paid activities nursery  studytime, granular higher internet romantic  \
# 241  yes         no     yes                 -6.0    yes      yes       no
# 348  yes        yes     yes                 -9.0    yes      yes      yes
# ...

# %%
# теперь разберемся с traveltime - 28 пропусков
show_common('traveltime')
# Out:
# 1.0    239
# 2.0     94
# NaN     28
# 3.0     21
# 4.0      7
# Name: traveltime, dtype: int64
#  traveltime all: 361

# %%
# посмотрим зависимость от reason - не очень понятно
draw_box('traveltime', 'reason', swap=False)

# %%
# в таком виде лучше видно, что можно пропуски заполнить значением 1
# на большую часть любых reason приходится traveltime = 1
for i in sc['reason'].unique():
    plt.scatter(x=sc[sc['reason'] == i]['traveltime'].value_counts().index,
                y=sc[sc['reason'] == i]['traveltime'].value_counts().values,
                s=sc[sc['reason'] == i]['traveltime'].value_counts().values*30,
                alpha=0.5, label=i)
plt.legend()

# %%
# заменяем traveltime на 1
sc['traveltime'].fillna(value=1, inplace=True)
show_common('traveltime')
# Out:
# 1.0    267
# 2.0     94
# 3.0     21
# 4.0      7
# Name: traveltime, dtype: int64
#  traveltime all: 389

# %%
# заполним оставшиеся 3 пустых address
# здесь и дальше некоторые пропущенные данные  будут заполняться на основе
# таким же образом заполненных пропущенных данных. Трудно сказать, насколько это хорошо

sc['address'] = sc.apply(lambda x: 'U' if x.traveltime < 2
                         else ('R' if x.traveltime > 1
                               else x.address), axis=1)
show_common('address')
# Out:
# U    267
# R    122
# Name: address, dtype: int64
#  address all: 389

# %%
# смотрим на famsize
show_common('famsize')
# Out:
# GT3    255
# LE3    107
# NaN     27
# Name: famsize, dtype: int64
#  famsize all: 362

# %%
# определим функцию для отрисовки
def scat(var1, var2, data=sc):
    for i in data[var1].unique():
        plt.scatter(x=data[data[var1] == i][var2].value_counts().index,
                    y=data[data[var1] == i][var2].value_counts().values,
                    s=data[data[var1] == i][var2].value_counts().values*30,
                    alpha=0.5, label=i)
    plt.legend()
    plt.xlabel('значения ' + var2)
    plt.ylabel('количество  ' + var1)

# %%
# в больших семьях guardian == 'mother'
scat('famsize', 'guardian')

# %%
# также в основном в больших семьях родители живут совместно
scat('famsize', 'Pstatus')

# %%
# также в больших семьях mother главная
scat('guardian', 'Pstatus')

# %%
# заполним пропуски в famsize значением GT3
sc['famsize'].fillna(value='GT3', inplace=True)

# %%
show_common('famsize')
# Out:
# GT3    282
# LE3    107
# Name: famsize, dtype: int64
#  famsize all: 389

# %%
# образование матери
show_common('Medu')
# Out:
# 4.0    131
# 2.0    100
# 3.0     96
# 1.0     56
# 0.0      3
# NaN      3
# Name: Medu, dtype: int64
#  Medu all: 386

# %%
# всего три пропуска, заполним медианой
sc.Medu.fillna(value=sc.Medu.median(), inplace=True)
show_common('Medu')
# Out:
# 4.0    131
# 2.0    100
# 3.0     99
# 1.0     56
# 0.0      3
# Name: Medu, dtype: int64
#  Medu all: 389

# %%
# образование отца
show_common('Fedu')
# Out:
# 2.0     105
# 3.0      94
# 4.0      88
# 1.0      75
# NaN      24
# 0.0       2
# 40.0      1
# Name: Fedu, dtype: int64
#  Fedu all: 365

# %%
# здесь какой-то выброс огромный
# посмотрим, что в нем
sc[sc['Fedu'] > 4]
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob   Fjob  \
# 11     GP   F   15       R     GT3     NaN   2.0  40.0  services  other
#
#         reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 11  reputation   father         3.0        3.0       0.0        no    yes
#
#    paid activities nursery  studytime, granular higher internet romantic  \
# 11   no        yes     yes                 -9.0    yes      yes       no
#
#     famrel  freetime  goout  health  absences  score
# 11     5.0       2.0    2.0     4.0       4.0   60.0

# %%
# скорее всего была ошибка при внесении данных, исправим
sc.loc[sc.Fedu > 4, 'Fedu'] = 4
show_common('Fedu')
# Out:
# 2.0    105
# 3.0     94
# 4.0     89
# 1.0     75
# NaN     24
# 0.0      2
# Name: Fedu, dtype: int64
#  Fedu all: 365

# %%
#
scat('Fedu', 'Fjob')

# %%
# заполним пропуски наиболее часто встречающимся по каждой категории Fjob

for i in sc.Fjob.unique():
    if not pd.isna(i):
        fedu_na = sc.loc[sc.Fjob == i, 'Fedu'].mode()[0]
        sc.loc[sc.Fedu.isna() & (sc.Fjob == i), ['Fedu']] = fedu_na
show_common('Fedu')
# Out:
# 2.0    114
# 3.0    102
# 4.0     94
# 1.0     75
# NaN      2
# 0.0      2
# Name: Fedu, dtype: int64
#  Fedu all: 387

# %%
# осталось 2 пропуска, посмотрим, что в них
sc[sc.Fedu.isna()]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob Fjob  \
# 161     GP   M   15       R     GT3       T   3.0   NaN  other  NaN
# 374     MS   F   18       R     LE3       T   4.0   NaN  other  NaN
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 161      course   mother         2.0        2.0       2.0       yes    yes
# 374  reputation   mother         2.0        3.0       0.0        no     no
#
#     paid activities nursery  studytime, granular higher internet romantic  \
# 161   no         no     yes                 -6.0    yes      yes      yes
# 374   no         no     yes                 -9.0    yes      yes       no
#
#      famrel  freetime  goout  health  absences  score
# 161     4.0       4.0    4.0     3.0       6.0   35.0
# 374     5.0       4.0    4.0     1.0       0.0   95.0

# %%
# остатки заполним медианой
sc.loc[sc.Fedu.isna(), ['Fedu']] = sc.Fedu.median()
show_common('Fedu')
# Out:
# 2.0    114
# 3.0    104
# 4.0     94
# 1.0     75
# 0.0      2
# Name: Fedu, dtype: int64
#  Fedu all: 389

# %%
# работа матери, 19 пропусков
show_common('Mjob')
# Out:
# other       127
# services     98
# at_home      58
# teacher      55
# health       32
# NaN          19
# Name: Mjob, dtype: int64
#  Mjob all: 370

# %%
# посмотрим на зависимости работы матери от ее образования
# бросается в глаза, что если высшее образование, то скорее всего это будет учитель
scat('Mjob', 'Medu')
draw_box('Mjob', 'Medu', swap=True)

# %%
# заодно посмотрим, как зависит работа матери от работы отца
scat('Fjob', 'Mjob')

# %%
# и наоборот
# в основном, где работает мать, там же и отец и наоборот )
scat('Mjob', 'Fjob')

# %%
# заполним пропуски в Mjob на основе следующего: Mjob=Fjob

sc['Mjob'] = sc.apply(lambda x: x.Fjob if pd.isna(x.Mjob) else x.Mjob, axis=1)
show_common('Mjob')
# Out:
# other       139
# services    102
# at_home      59
# teacher      56
# health       32
# NaN           1
# Name: Mjob, dtype: int64
#  Mjob all: 388

# %%
# что тут осталось

sc[sc.Mjob.isna()]
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu Mjob Fjob  reason  \
# 59     GP   F   16       U     GT3       T   4.0   2.0  NaN  NaN  course
#
#    guardian  traveltime  studytime  failures schoolsup famsup paid activities  \
# 59   mother         1.0        2.0       0.0        no    NaN   no         no
#
#    nursery  studytime, granular higher internet romantic  famrel  freetime  \
# 59     yes                 -6.0    yes      yes       no     4.0       2.0
#
#     goout  health  absences  score
# 59    3.0     5.0       2.0   80.0

# %%
# sex=F, Medu=4, Fedu=2, score=80 и т.п.
# как видно было выше, скорее всего Mjob=teacher
sc['Mjob'].fillna(value='teacher', inplace=True)
show_common('Mjob')
# Out:
# other       139
# services    102
# at_home      59
# teacher      57
# health       32
# Name: Mjob, dtype: int64
#  Mjob all: 389

# %%
# работу отца заполняем по аналогии с работой матери
sc['Fjob'] = sc.apply(lambda x: x.Mjob if pd.isna(x.Fjob) else x.Fjob, axis=1)
show_common('Fjob')
# Out:
# other       205
# services    109
# teacher      32
# at_home      22
# health       21
# Name: Fjob, dtype: int64
#  Fjob all: 389

# %%
# reason: 17 пропусков и score от причины выбора школы особо не зависит
# из всех этих графиков ниже складывается ощущение, что
# этим отцам (вне зависимости от образования и  их работы) практически п на детей

show_common('reason')
sc.reason.hist()
draw_box('score', 'reason', hue='school')
# Out:
# course        135
# reputation    102
# home          101
# other          34
# NaN            17
# Name: reason, dtype: int64
#  reason all: 372

# %%
fig, ax = plt.subplots(figsize=(12, 16))
plt.subplot(4, 2, 1)
scat('Medu', 'reason')
plt.subplot(4, 2, 2)
scat('reason', 'Medu')
plt.subplot(4, 2, 3)
scat('Fedu', 'reason')
plt.subplot(4, 2, 4)
scat('reason', 'Fedu')
plt.subplot(4, 2, 5)
scat('Mjob', 'reason')
plt.subplot(4, 2, 6)
scat('reason', 'Mjob')
plt.subplot(4, 2, 7)
scat('Fjob', 'reason')
plt.subplot(4, 2, 8)
scat('reason', 'Fjob')
# в основном родители выбирают reason==course | reputation
# причем reputation выбирают те, кто у кого job == health
# а кого job == other выбирают практически одинаково между всеми reason

# %%
# если посмотреть на опекуна,то mother - это больше половины, а они берут в основном course
show_common('guardian')
scat('reason', 'guardian')
# Out:
# mother    248
# father     86
# NaN        31
# other      24
# Name: guardian, dtype: int64
#  guardian all: 358

# %%
# итого: заполняем пропущенные reason следующим образом:
# если Mjob или Fjob == health, тогда reputation
# если job != other => course

sc.loc[sc.reason.isna() & ((sc.Fjob == 'health') | (
    sc.Mjob == 'health')), 'reason'] = 'reputation'
sc.loc[sc.reason.isna() & ((sc.Fjob != 'other') | (
    sc.Mjob != 'other')), 'reason'] = 'course'
# остальные равномерно между course, home, reputation
# зачем так сложно - непонятно, ибо получается, что reason будет зависеть от job,
# но на score это особо не должно повлиять
# поскольку я уже не знаю, как заполнять интервально, то остатки заполним просто course
sc['reason'].fillna(value='course', inplace=True)
show_common('reason')
# Out:
# course        151
# reputation    103
# home          101
# other          34
# Name: reason, dtype: int64
#  reason all: 389

# %%
show_common('guardian')
sc.guardian.hist()
# Out:
# mother    248
# father     86
# NaN        31
# other      24
# Name: guardian, dtype: int64
#  guardian all: 358

# %%
# заполняем все пропущенные модой
sc.guardian.fillna(value=sc.guardian.mode()[0], inplace=True)
show_common('guardian')
# Out:
# mother    279
# father     86
# other      24
# Name: guardian, dtype: int64
#  guardian all: 389

# %%
# studytime
show_common('studytime')
# Out:
# 2.0    189
# 1.0    103
# 3.0     63
# 4.0     27
# NaN      7
# Name: studytime, dtype: int64
#  studytime all: 382

# %%
# видна зависимость от доп. обучения
draw_box('score', 'studytime')

# %%
# заполним медианой
sc.studytime.fillna(value=sc.studytime.median(), inplace=True)
show_common('studytime')
# Out:
# 2.0    196
# 1.0    103
# 3.0     63
# 4.0     27
# Name: studytime, dtype: int64
#  studytime all: 389

# %%
# смотрим failures
# в основном 0
show_common('failures')
sc.failures.hist()
# Out:
# 0.0    290
# 1.0     48
# NaN     22
# 2.0     15
# 3.0     14
# Name: failures, dtype: int64
#  failures all: 367

# %%
# заполняем на 0
sc.failures.fillna(value=sc.failures.mode()[0], inplace=True)
show_common('failures')
# Out:
# 0.0    312
# 1.0     48
# 2.0     15
# 3.0     14
# Name: failures, dtype: int64
#  failures all: 389

# %%
# дальше
# в основном все 'no'
show_common('schoolsup')
# Out:
# no     331
# yes     49
# NaN      9
# Name: schoolsup, dtype: int64
#  schoolsup all: 380

# %%
# заполняем модой
sc.schoolsup.fillna(value=sc.schoolsup.mode()[0], inplace=True)
show_common('schoolsup')
# Out:
# no     340
# yes     49
# Name: schoolsup, dtype: int64
#  schoolsup all: 389

# %%
# здесь интереснее
show_common('famsup')
# Out:
# yes    216
# no     135
# NaN     38
# Name: famsup, dtype: int64
#  famsup all: 351

# %%
# в больших семьях больше поддержки
scat('famsup', 'famsize')

# %%
# заполним 'yes', где famsize==GT3, а остальное 'no'
sc.loc[sc.famsup.isna() & (sc.famsize == 'GT3'), 'famsup'] = 'yes'
sc['famsup'].fillna(value='no', inplace=True)
show_common('famsup')
# Out:
# yes    242
# no     147
# Name: famsup, dtype: int64
#  famsup all: 389

# %%
# платные занятия
show_common('paid')
# Out:
# no     197
# yes    153
# NaN     39
# Name: paid, dtype: int64
#  paid all: 350

# %%
fig, ax = plt.subplots(figsize=(12, 16))
plt.subplot(4, 2, 1)
# единственное от чего явно зависит - если нет famsup, то и paid нет
scat('paid', 'famsup')
plt.subplot(4, 2, 2)
# не зависит от schoolsup. возможно имеет смысл расматривать выборку, где score.median > 60
scat('paid', 'schoolsup')
plt.subplot(4, 2, 3)
scat('paid', 'activities')  # activities не влияют - в основном нет платы
plt.subplot(4, 2, 4)
scat('paid', 'studytime')  # при значениях studytime == 1  нет paid
plt.subplot(4, 2, 5)
scat('paid', 'guardian')  # у опекунов мнения тоже почти поровну
plt.subplot(4, 2, 6)
scat('paid', 'absences')  # а вот здесь нужно разобраться с absences

# %%
# смотрим, что внутри
display(sc.absences.describe())
display(sc[sc.absences > 100])
# Out:
# count    378.000000
# mean       7.320106
# std       23.615525
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        8.000000
# max      385.000000
# Name: absences, dtype: float64
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 222     GP   F   16       U     GT3       T   2.0   3.0  services   teacher
# 390     MS   M   20       U     LE3       A   2.0   2.0  services  services
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 222   other   mother         1.0        2.0       0.0       yes    yes   no
# 390  course   mother         1.0        2.0       2.0        no    yes  yes
#
#     activities nursery  studytime, granular higher internet romantic  famrel  \
# 222         no     yes                 -6.0    yes      yes       no     2.0
# 390         no     yes                 -6.0    yes       no       no     5.0
#
#      freetime  goout  health  absences  score
# ...

# %%
# заменим медианой, чтобы не мешались, ибо на score эти значения не влияют - один отличник, другая троечник
sc.loc[sc.absences > 100, 'absences'] = sc[sc.absences < 100].absences.median()

# %%
# и еще раз посмотрим - ничего интересного
scat('paid', 'absences')

# %%
draw_box('paid', 'absences', swap=True, thresh=20)

# %%
# итак, вернемся к заполнению пропусков paid
# если famsup==no, то paid=no
# если studytime ==1, то paid=no
# остатки = yes
sc.loc[sc.paid.isna() & ((sc.studytime == 1) | (sc.famsup == 'no')), 'paid'] = 'no'
sc.paid.fillna(value='yes', inplace=True)
show_common('paid')
# Out:
# no     220
# yes    169
# Name: paid, dtype: int64
#  paid all: 389

# %%
# activities
show_common('activities')
# Out:
# yes    192
# no     183
# NaN     14
# Name: activities, dtype: int64
#  activities all: 375

# %%
# теперь я много буду рисовать 8^]
fig, ax = plt.subplots(figsize=(12, 20))

for i, j in enumerate(['Medu', 'Mjob', 'Fedu', 'Fjob', 'famrel', 'famsize', 'romantic', 'goout', 'health', 'internet']):
    plt.subplot(5, 2, i+1)
    scat('paid', j)

# %%
# что видим: Medu==4, Mjob==teacher и health==1 - здесь будет yes, в остальных случаях - no
# заполним пропуски
sc.loc[sc.activities.isna() & ((sc.health == 1) | (sc.Medu == 4) |
                               (sc.Mjob == 'teacher')), 'activities'] = 'yes'
sc.activities.fillna(value='no', inplace=True)
show_common('activities')
# Out:
# yes    199
# no     190
# Name: activities, dtype: int64
#  activities all: 389

# %%
show_common('nursery')
# Out:
# yes    297
# no      77
# NaN     15
# Name: nursery, dtype: int64
#  nursery all: 374

# %%
fig, ax = plt.subplots(figsize=(12, 30))

for i, j in enumerate(['Medu', 'Mjob', 'Fedu', 'Fjob', 'famrel', 'famsize',
                       'guardian', 'famsup', 'romantic', 'goout',
                       'health', 'internet', 'absences', 'score']):
    plt.subplot(7, 2, i+1)
    scat('nursery', j)

# %%
# меняем на yes
sc.nursery.fillna(value='yes', inplace=True)
show_common('nursery')
# Out:
# yes    312
# no      77
# Name: nursery, dtype: int64
#  nursery all: 389

# %%
# почти все хотят полусть ВО (как и все ходили в садик)
show_common('higher')
# Out:
# yes    350
# NaN     20
# no      19
# Name: higher, dtype: int64
#  higher all: 369

# %%
# графики просто так, для ознакомления
# интересное распределение score и чем лучше отношения в семье, тем больше хотят получить ВО
# (хотя, скорее всего это просто попадание в одну и ту же семью)
fig, ax = plt.subplots(figsize=(12, 30))

for i, j in enumerate(['Medu', 'Mjob', 'Fedu', 'Fjob', 'famrel', 'famsize',
                       'guardian', 'famsup', 'romantic', 'goout',
                       'health', 'internet', 'absences', 'score', 'nursery']):
    plt.subplot(8, 2, i+1)
    scat('higher', j)

# %%
# заполняем yes
sc.higher.fillna(value='yes', inplace=True)
show_common('higher')
# Out:
# yes    370
# no      19
# Name: higher, dtype: int64
#  higher all: 389

# %%
# интересно ...
(sc.nursery == sc.higher).sum()
# предположительно что-то из этого можно выкинуть
# Out:
# 305

# %%
# internet есть почти у 2/3
show_common('internet')
# Out:
# yes    300
# no      55
# NaN     34
# Name: internet, dtype: int64
#  internet all: 355

# %%
fig, ax = plt.subplots(figsize=(12, 30))
for i, j in enumerate(['Medu', 'Mjob', 'Fedu', 'Fjob', 'famrel', 'famsize',
                       'guardian', 'famsup', 'romantic', 'goout',
                       'health', 'higher', 'absences', 'score']):
    plt.subplot(8, 2, i+1)
    scat('internet', j)

# %%
# т.к. особо наличие internet не зависит от чего-то, то будет считать, что он есть и у оставшихся
sc.internet.fillna(value='yes', inplace=True)
show_common('internet')
# Out:
# yes    334
# no      55
# Name: internet, dtype: int64
#  internet all: 389

# %%
# romantic
show_common('romantic')
# Out:
# no     235
# yes    123
# NaN     31
# Name: romantic, dtype: int64
#  romantic all: 358

# %%
# влияет на score
draw_box('score', 'romantic', hue='sex')
draw_box('score', 'sex')

# %%
fig, ax = plt.subplots(figsize=(12, 30))
for i, j in enumerate(['famrel', 'famsize', 'guardian', 'freetime',
                       'goout', 'internet', 'health', 'higher',
                       'absences', 'score', 'age', 'sex', 'school']):
    plt.subplot(8, 2, i+1)
    scat('romantic', j)

# %%
draw_box('romantic', 'age', swap=True, hue='sex', thresh=20)

# %%
# будем считать, что у всех учащихся, чей возраст <= 16 лет romantic=no, у остальных yes
sc.loc[sc.romantic.isna() & (sc.age < 17), ['romantic']] = 'no'
sc.romantic.fillna(value='yes', inplace=True)
show_common('romantic')
# Out:
# no     253
# yes    136
# Name: romantic, dtype: int64
#  romantic all: 389

# %%
# famrel - есть какое-то неправильное значение:
# или неправильно внесли или на самом деле отношения не вписываются в шкалу
show_common('famrel')
# Out:
#  4.0    178
#  5.0     97
#  3.0     62
#  NaN     27
#  2.0     17
#  1.0      7
# -1.0      1
# Name: famrel, dtype: int64
#  famrel all: 362

# %%
# сразу исправим неправильное значение
sc.loc[sc.famrel < 1, ['famrel']] = 1
show_common('famrel')
# Out:
# 4.0    178
# 5.0     97
# 3.0     62
# NaN     27
# 2.0     17
# 1.0      8
# Name: famrel, dtype: int64
#  famrel all: 362

# %%
fig, ax = plt.subplots(figsize=(12, 30))
for i, j in enumerate(['Medu', 'Mjob', 'Fedu', 'Fjob', 'famsize', 'Pstatus',
                       'reason', 'famsup', 'guardian', 'goout',
                       'health', 'failures', 'absences', 'score',
                       'freetime', 'paid']):
    plt.subplot(8, 2, i+1)
    scat('famrel', j)

# %%
draw_box('famrel', 'score', swap=True)

# %%
# ничего явного не видно заполняем модой
sc.famrel.fillna(value=sc.famrel.mode()[0], inplace=True)
show_common('famrel')
# Out:
# 4.0    205
# 5.0     97
# 3.0     62
# 2.0     17
# 1.0      8
# Name: famrel, dtype: int64
#  famrel all: 389

# %%
# freetime
show_common('freetime')
# Out:
# 3.0    152
# 4.0    110
# 2.0     63
# 5.0     37
# 1.0     18
# NaN      9
# Name: freetime, dtype: int64
#  freetime all: 380

# %%
sc.freetime.hist(bins=9)

# %%
# по графикам ничего не удалось выяснить, поэтому заполним медианой
draw_box('freetime', 'score', swap=True)

# %%
sc.freetime.fillna(value=sc.freetime.median(), inplace=True)
show_common('freetime')
# Out:
# 3.0    161
# 4.0    110
# 2.0     63
# 5.0     37
# 1.0     18
# Name: freetime, dtype: int64
#  freetime all: 389

# %%
# goout зполним медианой
show_common('goout')
# Out:
# 3.0    126
# 2.0    101
# 4.0     81
# 5.0     51
# 1.0     23
# NaN      7
# Name: goout, dtype: int64
#  goout all: 382

# %%
sc.goout.fillna(value=sc.goout.median(), inplace=True)
show_common('goout')
# Out:
# 3.0    133
# 2.0    101
# 4.0     81
# 5.0     51
# 1.0     23
# Name: goout, dtype: int64
#  goout all: 389

# %%
# health
show_common('health')
# Out:
# 5.0    137
# 3.0     88
# 4.0     60
# 1.0     47
# 2.0     42
# NaN     15
# Name: health, dtype: int64
#  health all: 374

# %%
sc.health.hist()

# %%
draw_box('score', 'health')

# %%
fig, ax = plt.subplots(figsize=(12, 30))
for i, j in enumerate(['famsize', 'Pstatus',
                       'reason', 'famsup', 'guardian', 'goout',
                       'traveltime', 'failures', 'absences', 'score',
                       'freetime', 'studytime']):
    plt.subplot(8, 2, i+1)
    scat('health', j)

# %%
draw_box('health', 'failures', swap=True)

# %%
draw_box('health', 'absences')

# %%
# absences портит всю картину
# посмотрим пристально на него
sc.absences.hist(bins=30)
draw_box('absences', 'score', swap=True)
show_common('absences')
# Out:
# 0.0     110
# 2.0      60
# 4.0      54
# 6.0      30
# 8.0      20
# 10.0     17
# 14.0     12
# 12.0     12
# NaN      11
# 3.0       7
# 16.0      7
# 7.0       6
# 5.0       5
# 18.0      5
# 20.0      4
# 1.0       3
# 22.0      3
# 9.0       3
# 15.0      2
# 13.0      2
# 11.0      2
# 25.0      1
# 17.0      1
# 54.0      1
# 26.0      1
# 56.0      1
# 23.0      1
# 28.0      1
# 21.0      1
# 75.0      1
# 30.0      1
# 19.0      1
# 38.0      1
# 40.0      1
# 24.0      1
# Name: absences, dtype: int64
#  absences all: 378

# %%
# основное распределение идет до 20 по гистограмме
# заменим на медиану в распределении до 20, да и пропуски тоже
sc.loc[sc.absences > 20, 'absences'] = sc[sc.absences <= 20].absences.median()
sc.absences.fillna(value=sc.absences.median(), inplace=True)
draw_box('absences', 'score', swap=True)
show_common('absences')
# Out:
# 0.0     110
# 4.0      80
# 2.0      60
# 6.0      30
# 8.0      20
# 10.0     17
# 12.0     12
# 14.0     12
# 3.0       7
# 16.0      7
# 7.0       6
# 18.0      5
# 5.0       5
# 20.0      4
# 1.0       3
# 9.0       3
# 11.0      2
# 13.0      2
# 15.0      2
# 19.0      1
# 17.0      1
# Name: absences, dtype: int64
#  absences all: 389

# %%
# как-то подозрительно, что распределены значения absences
# четных намного больше, чем нечетных
sc.absences.hist(bins=20)
sc.absences.value_counts().reindex(sc.absences.value_counts().index.sort_values())
# Out:
# 0.0     110
# 1.0       3
# 2.0      60
# 3.0       7
# 4.0      80
# 5.0       5
# 6.0      30
# 7.0       6
# 8.0      20
# 9.0       3
# 10.0     17
# 11.0      2
# 12.0     12
# 13.0      2
# 14.0     12
# 15.0      2
# 16.0      7
# 17.0      1
# 18.0      5
# 19.0      1
# 20.0      4
# Name: absences, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(14, 4))
sns.boxplot(x=sc.score, y=sc[sc.absences % 2 ==
                             0].absences, ax=ax, medianprops={'color': 'red'})
plt.show()

# %%
# какая-то нопонятка
fig, ax = plt.subplots(figsize=(14, 4))
sns.boxplot(x=sc.score, y=sc[sc.absences % 2 ==
                             1].absences, ax=ax, medianprops={'color': 'red'})
plt.show()

# %%
# а проверим-ка одну догадку
sc[sc.score == 0]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 128     GP   M   18       U     GT3       T   2.0   2.0     other     other
# 130     GP   F   15       R     GT3       T   3.0   4.0  services   teacher
# 131     GP   F   15       R     GT3     NaN   1.0   1.0   at_home     other
# 134     GP   M   15       U     GT3       T   3.0   4.0   at_home   teacher
# 135     GP   F   15       U     GT3       T   4.0   4.0  services  services
# 136     GP   M   17       R     GT3       T   3.0   4.0   at_home     other
# 137     GP   F   16       U     GT3       A   3.0   2.0     other     other
# 140     GP   M   15       R     GT3       T   4.0   3.0   teacher  services
# 144     GP   M   17       U     GT3       T   2.0   1.0     other     other
# 146     GP   F   15       U     GT3       T   3.0   2.0    health  services
# 148     GP   M   16       U     GT3       T   4.0   4.0   teacher   teacher
# ...

# %%
# у всех score==0 absences также 0, кроме одного №150
print('score==0:', (sc.score == 0).sum())
print('absences==0:', (sc.absences == 0).sum())
# Out:
# score==0: 37
# absences==0: 110

# %%
# возьмем начальные данные и проверим №150 - у него absence==NaN
sc_old = pd.read_csv('stud_math.csv')
sc_old.iloc[150]
# Out:
# school                     GP
# sex                         M
# age                        18
# address                     U
# famsize                   LE3
# Pstatus                     T
# Medu                        1
# Fedu                        1
# Mjob                    other
# Fjob                    other
# reason                 course
# guardian               mother
# traveltime                  1
# studytime                   1
# failures                    3
# schoolsup                  no
# famsup                     no
# paid                       no
# activities                 no
# nursery                   yes
# studytime, granular        -3
# higher                     no
# internet                  yes
# romantic                  yes
# famrel                      2
# freetime                    3
# goout                       5
# health                      4
# absences                  NaN
# score                       0
# Name: 150, dtype: object

# %%
# значит поменяем его на 0
sc.loc[(sc.absences > 0) & (sc.score < 1), 'absences'] = 0

# %%
sc.iloc[150]
# Out:
# school                     GP
# sex                         M
# age                        18
# address                     U
# famsize                   LE3
# Pstatus                     T
# Medu                        1
# Fedu                        1
# Mjob                    other
# Fjob                    other
# reason                 course
# guardian               mother
# traveltime                  1
# studytime                   1
# failures                    3
# schoolsup                  no
# famsup                     no
# paid                       no
# activities                 no
# nursery                   yes
# studytime, granular        -3
# higher                     no
# internet                  yes
# romantic                  yes
# famrel                      2
# freetime                    3
# goout                       5
# health                      4
# absences                    0
# score                       0
# Name: 150, dtype: object

# %%
# можно предположить, что это
# какие-то тихие двоечники или класс альтернативно одаренных или у них математика не прудусмотренна,
# а также у них нет schoolsup, но есть paid, значит математика идет факультативом и экзамен не нужен,
# в любом случае, наверное это как-то нужно пометить отдельной колонкой,
# где 1 означает, что есть экзамен, а 0 - нет
# это действительно интересно - найти такие данные :)
# лучше бы из удалить, но вдруг в следующий раз снова придут такие данные и модель ошибется на этом
sc['score1'] = sc.score.apply(lambda x: 1 if x > 0 else 0)
show_common('score1')
# Out:
# 1    352
# 0     37
# Name: score1, dtype: int64
#  score1 all: 389

# %%
# вернемся к health и заполним медианой пропуски
sc.health.fillna(value=sc.health.median(), inplace=True)
show_common('health')
# Out:
# 5.0    137
# 3.0     88
# 4.0     75
# 1.0     47
# 2.0     42
# Name: health, dtype: int64
#  health all: 389

# %%
# остался еще недокументированный столбец 'studytime, granular'
# еще раньше заметил, что он кратен studytime
# проверим
pd.Series(sc['studytime, granular']/sc['studytime']).value_counts()
# Out:
# -3.0    382
# dtype: int64

# %%
# не знаю, что означает сей столбей, но он явно не нужен, удаляем
sc.drop(columns=['studytime, granular'], inplace=True)
sc.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout',
#        'health', 'absences', 'score', 'score1'],
#       dtype='object')

# %%
# проверим полноту заполнения
sc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 389 entries, 0 to 394
# Data columns (total 30 columns):
# school        389 non-null object
# sex           389 non-null object
# age           389 non-null int64
# address       389 non-null object
# famsize       389 non-null object
# Pstatus       344 non-null object
# Medu          389 non-null float64
# Fedu          389 non-null float64
# Mjob          389 non-null object
# Fjob          389 non-null object
# reason        389 non-null object
# guardian      389 non-null object
# traveltime    389 non-null float64
# studytime     389 non-null float64
# failures      389 non-null float64
# schoolsup     389 non-null object
# famsup        389 non-null object
# paid          389 non-null object
# activities    389 non-null object
# nursery       389 non-null object
# higher        389 non-null object
# internet      389 non-null object
# romantic      389 non-null object
# famrel        389 non-null float64
# ...

# %%
# забыл про Pstatus
show_common('Pstatus')
# Out:
# T      308
# NaN     45
# A       36
# Name: Pstatus, dtype: int64
#  Pstatus all: 344

# %%
fig, ax = plt.subplots(figsize=(12, 20))

for i, j in enumerate(['Medu', 'Mjob', 'Fedu', 'Fjob', 'famrel', 'famsize', 'guardian']):
    plt.subplot(5, 2, i+1)
    scat('Pstatus', j)

# %%
# вроде не отчего не зависит, заменяем на моду
sc.Pstatus.fillna(value=sc.Pstatus.mode()[0], inplace=True)
show_common('Pstatus')
# Out:
# T    353
# A     36
# Name: Pstatus, dtype: int64
#  Pstatus all: 389

# %%
# и проверим на дубликаты изначальные данные
sc_old.duplicated().value_counts()
# Out:
# False    395
# dtype: int64

# %%
# снова проерим полноту данных - не забыл ли что-то
sc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 389 entries, 0 to 394
# Data columns (total 30 columns):
# school        389 non-null object
# sex           389 non-null object
# age           389 non-null int64
# address       389 non-null object
# famsize       389 non-null object
# Pstatus       389 non-null object
# Medu          389 non-null float64
# Fedu          389 non-null float64
# Mjob          389 non-null object
# Fjob          389 non-null object
# reason        389 non-null object
# guardian      389 non-null object
# traveltime    389 non-null float64
# studytime     389 non-null float64
# failures      389 non-null float64
# schoolsup     389 non-null object
# famsup        389 non-null object
# paid          389 non-null object
# activities    389 non-null object
# nursery       389 non-null object
# higher        389 non-null object
# internet      389 non-null object
# romantic      389 non-null object
# famrel        389 non-null float64
# ...

# %%
# все в порядке, всё заполнено
# теперь все yes заменим на 1 no - на 0
sc.replace('yes', 1, inplace=True)
sc.replace('no', 0, inplace=True)
sc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 389 entries, 0 to 394
# Data columns (total 30 columns):
# school        389 non-null object
# sex           389 non-null object
# age           389 non-null int64
# address       389 non-null object
# famsize       389 non-null object
# Pstatus       389 non-null object
# Medu          389 non-null float64
# Fedu          389 non-null float64
# Mjob          389 non-null object
# Fjob          389 non-null object
# reason        389 non-null object
# guardian      389 non-null object
# traveltime    389 non-null float64
# studytime     389 non-null float64
# failures      389 non-null float64
# schoolsup     389 non-null int64
# famsup        389 non-null int64
# paid          389 non-null int64
# activities    389 non-null int64
# nursery       389 non-null int64
# higher        389 non-null int64
# internet      389 non-null int64
# romantic      389 non-null int64
# famrel        389 non-null float64
# ...

# %%
# посмотрим, что коррелирует между собой
# я считаю, что можно испольовать столбцы типа freetime
# (— свободное время после школы (от 1 - очень мало до 5 - очень много))

sc[['traveltime', 'studytime', 'failures', 'famrel',
    'absences', 'health', 'goout', 'freetime', 'score']].corr()
# Out:
#             traveltime  studytime  failures    famrel  absences    health  \
# traveltime    1.000000  -0.098226  0.035113 -0.029213 -0.037328 -0.035852
# studytime    -0.098226   1.000000 -0.169399  0.037950 -0.069362 -0.072790
# failures      0.035113  -0.169399  1.000000 -0.028517  0.067149  0.082165
# famrel       -0.029213   0.037950 -0.028517  1.000000 -0.078381  0.088845
# absences     -0.037328  -0.069362  0.067149 -0.078381  1.000000 -0.012930
# health       -0.035852  -0.072790  0.082165  0.088845 -0.012930  1.000000
# goout         0.046390  -0.053554  0.101036  0.069514  0.101652 -0.016427
# freetime     -0.016696  -0.122057  0.087558  0.164830  0.089815  0.063718
# score        -0.056535   0.114295 -0.337187  0.052902  0.081789 -0.073208
#
#                goout  freetime     score
# traveltime  0.046390 -0.016696 -0.056535
# studytime  -0.053554 -0.122057  0.114295
# failures    0.101036  0.087558 -0.337187
# famrel      0.069514  0.164830  0.052902
# ...

# %%
# убираем всё, что меньше 0.1
# заодно заведем список ненужных колонок
sc_drop = ['traveltime', 'famrel', 'absences', 'health', 'freetime']

# %%
# дальше пойдем по порядку сначала, определяя нужна нам переменная или нет,
# заменяя значения или добавляя новые колонки
#
# школа
draw_box('score', 'school')

# %%
# будем считать, что модель нужна будет только для предсказания в этих двух школах, поэтому
# добавим новые колонки

sc = pd.concat([sc, pd.get_dummies(sc['school'])], axis=1)
sc.info()

sc_drop.append('school')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 389 entries, 0 to 394
# Data columns (total 32 columns):
# school        389 non-null object
# sex           389 non-null object
# age           389 non-null int64
# address       389 non-null object
# famsize       389 non-null object
# Pstatus       389 non-null object
# Medu          389 non-null float64
# Fedu          389 non-null float64
# Mjob          389 non-null object
# Fjob          389 non-null object
# reason        389 non-null object
# guardian      389 non-null object
# traveltime    389 non-null float64
# studytime     389 non-null float64
# failures      389 non-null float64
# schoolsup     389 non-null int64
# famsup        389 non-null int64
# paid          389 non-null int64
# activities    389 non-null int64
# nursery       389 non-null int64
# higher        389 non-null int64
# internet      389 non-null int64
# romantic      389 non-null int64
# famrel        389 non-null float64
# ...

# %%
# sex
draw_box('score', 'sex')

# %%
# зависит, добавим новые колонки

sc = pd.concat([sc, pd.get_dummies(sc['sex'])], axis=1)
sc.info()
sc_drop.append('sex')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 389 entries, 0 to 394
# Data columns (total 34 columns):
# school        389 non-null object
# sex           389 non-null object
# age           389 non-null int64
# address       389 non-null object
# famsize       389 non-null object
# Pstatus       389 non-null object
# Medu          389 non-null float64
# Fedu          389 non-null float64
# Mjob          389 non-null object
# Fjob          389 non-null object
# reason        389 non-null object
# guardian      389 non-null object
# traveltime    389 non-null float64
# studytime     389 non-null float64
# failures      389 non-null float64
# schoolsup     389 non-null int64
# famsup        389 non-null int64
# paid          389 non-null int64
# activities    389 non-null int64
# nursery       389 non-null int64
# higher        389 non-null int64
# internet      389 non-null int64
# romantic      389 non-null int64
# famrel        389 non-null float64
# ...

# %%
# age
draw_box('score', 'age', swap=True)

# %%
# нужен, оставляем и добавляем
sc = pd.concat([sc, pd.get_dummies(sc['age'])], axis=1)
sc.info()
sc_drop.append('age')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 389 entries, 0 to 394
# Data columns (total 42 columns):
# school        389 non-null object
# sex           389 non-null object
# age           389 non-null int64
# address       389 non-null object
# famsize       389 non-null object
# Pstatus       389 non-null object
# Medu          389 non-null float64
# Fedu          389 non-null float64
# Mjob          389 non-null object
# Fjob          389 non-null object
# reason        389 non-null object
# guardian      389 non-null object
# traveltime    389 non-null float64
# studytime     389 non-null float64
# failures      389 non-null float64
# schoolsup     389 non-null int64
# famsup        389 non-null int64
# paid          389 non-null int64
# activities    389 non-null int64
# nursery       389 non-null int64
# higher        389 non-null int64
# internet      389 non-null int64
# romantic      389 non-null int64
# famrel        389 non-null float64
# ...

# %%
# address
draw_box('score', 'address')

# %%
sc = pd.concat([sc, pd.get_dummies(sc['address'])], axis=1)
sc.info()
sc_drop.append('address')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 389 entries, 0 to 394
# Data columns (total 44 columns):
# school        389 non-null object
# sex           389 non-null object
# age           389 non-null int64
# address       389 non-null object
# famsize       389 non-null object
# Pstatus       389 non-null object
# Medu          389 non-null float64
# Fedu          389 non-null float64
# Mjob          389 non-null object
# Fjob          389 non-null object
# reason        389 non-null object
# guardian      389 non-null object
# traveltime    389 non-null float64
# studytime     389 non-null float64
# failures      389 non-null float64
# schoolsup     389 non-null int64
# famsup        389 non-null int64
# paid          389 non-null int64
# activities    389 non-null int64
# nursery       389 non-null int64
# higher        389 non-null int64
# internet      389 non-null int64
# romantic      389 non-null int64
# famrel        389 non-null float64
# ...

# %%
# просто не нужна колонка
draw_box('score', 'famsize')
sc_drop.append('famsize')

# %%
# просто не нужна колонка
draw_box('score', 'Pstatus')
sc_drop.append('Pstatus')

# %%
# нужна колонка
draw_box('Medu', 'score')

# %%
sc = pd.concat([sc, pd.get_dummies(sc['Medu'], prefix='Medu')], axis=1)
sc_drop.append('Medu')

# %%
# нужно
draw_box('Fedu', 'score')

# %%
sc = pd.concat([sc, pd.get_dummies(sc['Fedu'], prefix='Fedu')], axis=1)
sc_drop.append('Fedu')

# %%
# нужно
draw_box('Mjob', 'score')

# %%
sc = pd.concat([sc, pd.get_dummies(sc['Mjob'], prefix='Mjob')], axis=1)
sc_drop.append('Mjob')

# %%
# нужно только из-за teacher
draw_box('Fjob', 'score')

# %%
sc = pd.concat([sc, pd.get_dummies(sc['Fjob'], prefix='Fjob')], axis=1)
sc_drop.append('Fjob')

# %%
# reason не нужен
draw_box('reason', 'score')

# %%
sc_drop.append('reason')

# %%
# guardian не нужен
draw_box('guardian', 'score')

# %%
sc_drop.append('guardian')

# %%
# traveltime уже добавлен в ненужные

# %%
# studytime, failures,  оставляем как есть - всё же показывает меру

# %%
# schoolsup оставляем
draw_box('schoolsup', 'score')

# %%
# famsup не нужен
draw_box('famsup', 'score')
sc_drop.append('famsup')

# %%
# paid не нужен
draw_box('paid', 'score', hue='activities')
sc_drop.append('paid')

# %%
# activities не нужен
draw_box('activities', 'score', hue='paid')
sc_drop.append('activities')

# %%
# nursery не нужен
draw_box('nursery', 'score')
sc_drop.append('nursery')

# %%
# higher нужен
draw_box('higher', 'score')

# %%
# internet не нужен
draw_box('internet', 'score')
sc_drop.append('internet')

# %%
# romantic нужен
draw_box('romantic', 'score')

# %%
# famrel, freetime, goout, health, absences уже рассмотрели выше при корреляции

# %%
# итого имеем ненужные столбцы:
sc_drop
# Out:
# ['traveltime',
#  'famrel',
#  'absences',
#  'health',
#  'freetime',
#  'school',
#  'sex',
#  'age',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Medu',
#  'Fedu',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'internet']

# %%
# готовый DF
sc_ready = sc.drop(columns=sc_drop)

# %%
sc_ready.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 389 entries, 0 to 394
# Data columns (total 42 columns):
# studytime        389 non-null float64
# failures         389 non-null float64
# schoolsup        389 non-null int64
# higher           389 non-null int64
# romantic         389 non-null int64
# goout            389 non-null float64
# score            389 non-null float64
# score1           389 non-null int64
# GP               389 non-null uint8
# MS               389 non-null uint8
# F                389 non-null uint8
# M                389 non-null uint8
# 15               389 non-null uint8
# 16               389 non-null uint8
# 17               389 non-null uint8
# 18               389 non-null uint8
# 19               389 non-null uint8
# 20               389 non-null uint8
# 21               389 non-null uint8
# 22               389 non-null uint8
# R                389 non-null uint8
# U                389 non-null uint8
# Medu_0.0         389 non-null uint8
# ...
